# %%
# Import Dependencies
import pandas as pd

# %%
# Read in Covid-19 and deaths data source
covid_19_deaths = pd.read_csv("covid_deaths.csv")
covid_19_deaths
# Out:
#          Country                         State  Jan_sum  Feb_sum  Mar_sum  \
# 0      Australia  Australian Capital Territory        0        0        2
# 1      Australia               New South Wales        0        0      120
# 2      Australia            Northern Territory        0        0        0
# 3      Australia                    Queensland        0        0        9
# 4      Australia               South Australia        0        0        0
# 5      Australia                      Tasmania        0        0        1
# 6      Australia                      Victoria        0        0       21
# 7      Australia             Western Australia        0        0       37
# 8         Brazil                           NaN        0        0      976
# 9          China                         Anhui        0      113      186
# 10         China                       Beijing        5       93      248
# 11         China                     Chongqing        0      119      186
# ...
